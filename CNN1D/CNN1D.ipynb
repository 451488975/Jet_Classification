# %%
import keras
from keras.layers import Input, Dense, Flatten, Conv1D
from keras.models import load_model, Model
import sys
import yaml
from keras.regularizers import l1
from keras.optimizers import Adam
sys.path.insert(0,'../lib')
from train import get_features
from evaluation import makeRoc, learningCurveLoss
# Out:
# Using TensorFlow backend.

# %%
from collections import namedtuple
Option = namedtuple("MyStruct", "inputModel inputFile tree config")
options = Option(
    inputModel = 'KERAS_conv1d_weights.h5',
    inputFile = '../processed-pythia82-lhc13-all-pt1-50k-r1_h022_e0175_t220_nonu_withPars_truth_0.z',
    tree = 't_allpar_new',
    config = 'train_config_conv1d.yml',
)

print("Loading configuration from", options.config)
config = open(options.config, 'r')
yamlConfig =  yaml.load(config, Loader = yaml.FullLoader)
yamlConfig
# Out:
# Loading configuration from train_config_conv1d.yml
# {'Inputs': ['j1_ptrel',
#   'j1_etarot',
#   'j1_phirot',
#   'j1_erel',
#   'j1_deltaR',
#   'j1_costhetarel',
#   'j1_pdgid',
#   'j_index'],
#  'Labels': ['j_g', 'j_q', 'j_w', 'j_z', 'j_t', 'j_index'],
#  'KerasModel': 'conv1d_model',
#  'KerasModelRetrain': 'conv1d_model_constraint',
#  'KerasLoss': 'categorical_crossentropy',
#  'L1Reg': 0.0001,
#  'NormalizeInputs': 1,
#  'InputType': 'Conv1D',
#  'MaxParticles': 100}

# %% [markdown]
# # Train

# %%
X_train_val, X_test, y_train_val, y_test, labels = get_features(options, yamlConfig)
# Out:
# (5131613,)
# ('index', 'j_ptfrac', 'j_pt', 'j_eta', 'j_mass', 'j_tau1_b1', 'j_tau2_b1', 'j_tau3_b1', 'j_tau1_b2', 'j_tau2_b2', 'j_tau3_b2', 'j_tau32_b1', 'j_tau32_b2', 'j_zlogz', 'j_c1_b0', 'j_c1_b1', 'j_c1_b2', 'j_c2_b1', 'j_c2_b2', 'j_d2_b1', 'j_d2_b2', 'j_d2_a1_b1', 'j_d2_a1_b2', 'j_m2_b1', 'j_m2_b2', 'j_n2_b1', 'j_n2_b2', 'j_tau1_b1_mmdt', 'j_tau2_b1_mmdt', 'j_tau3_b1_mmdt', 'j_tau1_b2_mmdt', 'j_tau2_b2_mmdt', 'j_tau3_b2_mmdt', 'j_tau32_b1_mmdt', 'j_tau32_b2_mmdt', 'j_c1_b0_mmdt', 'j_c1_b1_mmdt', 'j_c1_b2_mmdt', 'j_c2_b1_mmdt', 'j_c2_b2_mmdt', 'j_d2_b1_mmdt', 'j_d2_b2_mmdt', 'j_d2_a1_b1_mmdt', 'j_d2_a1_b2_mmdt', 'j_m2_b1_mmdt', 'j_m2_b2_mmdt', 'j_n2_b1_mmdt', 'j_n2_b2_mmdt', 'j_mass_trim', 'j_mass_mmdt', 'j_mass_prun', 'j_mass_sdb2', 'j_mass_sdm1', 'j_multiplicity', 'j1_px', 'j1_py', 'j1_pz', 'j1_e', 'j1_pdgid', 'j1_erel', 'j1_pt', 'j1_ptrel', 'j1_eta', 'j1_etarel', 'j1_etarot', 'j1_phi', 'j1_phirel', 'j1_phirot', 'j1_deltaR', 'j1_costheta', 'j1_costhetarel', 'j1_e1mcosthetarel', 'j_g', 'j_q', 'j_w', 'j_z', 'j_t', 'j_undef', 'j_index')
# (98769, 5)

# %% [markdown]
# # Self-Build Model

# %%
l1Reg = yamlConfig['L1Reg']
Inputs = Input(shape = (100,7))
x = Conv1D(filters= 8, kernel_size=4, strides=1, padding='same',
               kernel_initializer='he_normal', use_bias=True, name='conv1_relu_1',
               activation = 'relu', kernel_regularizer=l1(l1Reg))(Inputs)
x = Conv1D(filters= 4, kernel_size=4, strides=2, padding='same',
               kernel_initializer='he_normal', use_bias=True, name='conv1_relu_2',
               activation = 'relu', kernel_regularizer=l1(l1Reg))(x)
x = Conv1D(filters=2, kernel_size=4, strides=3, padding='same',
               kernel_initializer='he_normal', use_bias=True, name='conv1_relu_3',
               activation = 'relu', kernel_regularizer=l1(l1Reg))(x)
x = Flatten()(x)
x = Dense(32, activation='relu', kernel_initializer='lecun_uniform', 
              name='fc1_relu', kernel_regularizer=l1(l1Reg))(x)
predictions = Dense(5, activation='softmax', kernel_initializer='lecun_uniform', name='rnn_densef')(x)
model = Model(inputs=Inputs, outputs=predictions)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100, 7)]          0
# _________________________________________________________________
# conv1_relu_1 (Conv1D)        (None, 100, 8)            232
# _________________________________________________________________
# conv1_relu_2 (Conv1D)        (None, 50, 4)             132
# _________________________________________________________________
# conv1_relu_3 (Conv1D)        (None, 17, 2)             34
# _________________________________________________________________
# flatten (Flatten)            (None, 34)                0
# _________________________________________________________________
# fc1_relu (Dense)             (None, 32)                1120
# _________________________________________________________________
# rnn_densef (Dense)           (None, 5)                 165
# =================================================================
# Total params: 1,683
# Trainable params: 1,683
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = Adam(lr = 0.0001)
model.compile(optimizer=adam, loss=[yamlConfig['KerasLoss']], metrics=['accuracy'])

history = model.fit(X_train_val, y_train_val, batch_size = 1024, epochs = 100, 
                    validation_split = 0.25, shuffle = True, callbacks = None,
                    use_multiprocessing=True, workers=4)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 1s 14ms/step - loss: 1.6398 - accuracy: 0.1729 - val_loss: 1.6348 - val_accuracy: 0.1831
# Epoch 2/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.6313 - accuracy: 0.1988 - val_loss: 1.6278 - val_accuracy: 0.2220
# Epoch 3/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.6242 - accuracy: 0.2382 - val_loss: 1.6204 - val_accuracy: 0.2465
# Epoch 4/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.6151 - accuracy: 0.2605 - val_loss: 1.6100 - val_accuracy: 0.2649
# Epoch 5/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.6018 - accuracy: 0.2806 - val_loss: 1.5948 - val_accuracy: 0.2842
# Epoch 6/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.5836 - accuracy: 0.2953 - val_loss: 1.5747 - val_accuracy: 0.3021
# Epoch 7/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.5615 - accuracy: 0.3092 - val_loss: 1.5513 - val_accuracy: 0.3134
# Epoch 8/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.5369 - accuracy: 0.3215 - val_loss: 1.5257 - val_accuracy: 0.3243
# Epoch 9/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.5105 - accuracy: 0.3324 - val_loss: 1.4988 - val_accuracy: 0.3367
# Epoch 10/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.4831 - accuracy: 0.3446 - val_loss: 1.4715 - val_accuracy: 0.3485
# Epoch 11/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.4555 - accuracy: 0.3585 - val_loss: 1.4443 - val_accuracy: 0.3635
# Epoch 12/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.4284 - accuracy: 0.3717 - val_loss: 1.4177 - val_accuracy: 0.3804
# Epoch 13/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.4022 - accuracy: 0.3868 - val_loss: 1.3918 - val_accuracy: 0.3973
# Epoch 14/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.3768 - accuracy: 0.4034 - val_loss: 1.3665 - val_accuracy: 0.4148
# Epoch 15/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.3517 - accuracy: 0.4209 - val_loss: 1.3421 - val_accuracy: 0.4312
# Epoch 16/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.3276 - accuracy: 0.4370 - val_loss: 1.3187 - val_accuracy: 0.4451
# Epoch 17/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.3046 - accuracy: 0.4519 - val_loss: 1.2965 - val_accuracy: 0.4612
# Epoch 18/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2830 - accuracy: 0.4661 - val_loss: 1.2761 - val_accuracy: 0.4727
# Epoch 19/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2634 - accuracy: 0.4782 - val_loss: 1.2578 - val_accuracy: 0.4841
# Epoch 20/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2457 - accuracy: 0.4893 - val_loss: 1.2412 - val_accuracy: 0.4931
# Epoch 21/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2297 - accuracy: 0.5005 - val_loss: 1.2257 - val_accuracy: 0.5029
# Epoch 22/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2147 - accuracy: 0.5113 - val_loss: 1.2109 - val_accuracy: 0.5142
# Epoch 23/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2000 - accuracy: 0.5208 - val_loss: 1.1968 - val_accuracy: 0.5248
# Epoch 24/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1859 - accuracy: 0.5298 - val_loss: 1.1822 - val_accuracy: 0.5345
# Epoch 25/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1719 - accuracy: 0.5386 - val_loss: 1.1685 - val_accuracy: 0.5427
# Epoch 26/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1585 - accuracy: 0.5462 - val_loss: 1.1546 - val_accuracy: 0.5485
# Epoch 27/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1456 - accuracy: 0.5535 - val_loss: 1.1412 - val_accuracy: 0.5552
# Epoch 28/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1332 - accuracy: 0.5586 - val_loss: 1.1288 - val_accuracy: 0.5605
# Epoch 29/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1216 - accuracy: 0.5631 - val_loss: 1.1170 - val_accuracy: 0.5676
# Epoch 30/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1106 - accuracy: 0.5678 - val_loss: 1.1064 - val_accuracy: 0.5719
# Epoch 31/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1005 - accuracy: 0.5719 - val_loss: 1.0954 - val_accuracy: 0.5786
# Epoch 32/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0909 - accuracy: 0.5756 - val_loss: 1.0860 - val_accuracy: 0.5811
# Epoch 33/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0817 - accuracy: 0.5804 - val_loss: 1.0769 - val_accuracy: 0.5842
# Epoch 34/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0734 - accuracy: 0.5847 - val_loss: 1.0685 - val_accuracy: 0.5863
# Epoch 35/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0655 - accuracy: 0.5879 - val_loss: 1.0605 - val_accuracy: 0.5900
# Epoch 36/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0581 - accuracy: 0.5911 - val_loss: 1.0533 - val_accuracy: 0.5917
# Epoch 37/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0511 - accuracy: 0.5942 - val_loss: 1.0461 - val_accuracy: 0.5919
# Epoch 38/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0445 - accuracy: 0.5958 - val_loss: 1.0397 - val_accuracy: 0.5966
# Epoch 39/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0384 - accuracy: 0.5983 - val_loss: 1.0335 - val_accuracy: 0.6000
# Epoch 40/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0327 - accuracy: 0.6003 - val_loss: 1.0278 - val_accuracy: 0.6005
# Epoch 41/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0275 - accuracy: 0.6024 - val_loss: 1.0228 - val_accuracy: 0.6037
# Epoch 42/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0228 - accuracy: 0.6041 - val_loss: 1.0178 - val_accuracy: 0.6048
# Epoch 43/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0182 - accuracy: 0.6065 - val_loss: 1.0132 - val_accuracy: 0.6070
# Epoch 44/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0140 - accuracy: 0.6072 - val_loss: 1.0091 - val_accuracy: 0.6109
# Epoch 45/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0101 - accuracy: 0.6093 - val_loss: 1.0051 - val_accuracy: 0.6123
# Epoch 46/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0064 - accuracy: 0.6108 - val_loss: 1.0013 - val_accuracy: 0.6139
# Epoch 47/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0029 - accuracy: 0.6111 - val_loss: 0.9978 - val_accuracy: 0.6146
# Epoch 48/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9995 - accuracy: 0.6136 - val_loss: 0.9947 - val_accuracy: 0.6164
# Epoch 49/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9964 - accuracy: 0.6143 - val_loss: 0.9914 - val_accuracy: 0.6160
# Epoch 50/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9935 - accuracy: 0.6158 - val_loss: 0.9886 - val_accuracy: 0.6171
# Epoch 51/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9907 - accuracy: 0.6162 - val_loss: 0.9862 - val_accuracy: 0.6195
# Epoch 52/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9881 - accuracy: 0.6172 - val_loss: 0.9835 - val_accuracy: 0.6183
# Epoch 53/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9856 - accuracy: 0.6179 - val_loss: 0.9811 - val_accuracy: 0.6203
# Epoch 54/100
# 58/58 [==============================] - 0s 8ms/step - loss: 0.9832 - accuracy: 0.6189 - val_loss: 0.9788 - val_accuracy: 0.6217
# Epoch 55/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9808 - accuracy: 0.6198 - val_loss: 0.9768 - val_accuracy: 0.6223
# Epoch 56/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9789 - accuracy: 0.6215 - val_loss: 0.9743 - val_accuracy: 0.6206
# Epoch 57/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9765 - accuracy: 0.6211 - val_loss: 0.9725 - val_accuracy: 0.6225
# Epoch 58/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9744 - accuracy: 0.6213 - val_loss: 0.9706 - val_accuracy: 0.6255
# Epoch 59/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9725 - accuracy: 0.6235 - val_loss: 0.9690 - val_accuracy: 0.6249
# Epoch 60/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9706 - accuracy: 0.6238 - val_loss: 0.9669 - val_accuracy: 0.6264
# Epoch 61/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9688 - accuracy: 0.6247 - val_loss: 0.9652 - val_accuracy: 0.6269
# Epoch 62/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9670 - accuracy: 0.6256 - val_loss: 0.9635 - val_accuracy: 0.6267
# Epoch 63/100
# 58/58 [==============================] - 0s 8ms/step - loss: 0.9653 - accuracy: 0.6262 - val_loss: 0.9618 - val_accuracy: 0.6273
# Epoch 64/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9636 - accuracy: 0.6275 - val_loss: 0.9605 - val_accuracy: 0.6293
# Epoch 65/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9620 - accuracy: 0.6275 - val_loss: 0.9588 - val_accuracy: 0.6290
# Epoch 66/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9604 - accuracy: 0.6295 - val_loss: 0.9574 - val_accuracy: 0.6303
# Epoch 67/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9591 - accuracy: 0.6297 - val_loss: 0.9560 - val_accuracy: 0.6308
# Epoch 68/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9575 - accuracy: 0.6304 - val_loss: 0.9547 - val_accuracy: 0.6319
# Epoch 69/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9560 - accuracy: 0.6312 - val_loss: 0.9534 - val_accuracy: 0.6330
# Epoch 70/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9547 - accuracy: 0.6317 - val_loss: 0.9520 - val_accuracy: 0.6326
# Epoch 71/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9534 - accuracy: 0.6320 - val_loss: 0.9507 - val_accuracy: 0.6325
# Epoch 72/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9520 - accuracy: 0.6333 - val_loss: 0.9496 - val_accuracy: 0.6342
# Epoch 73/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9509 - accuracy: 0.6340 - val_loss: 0.9485 - val_accuracy: 0.6348
# Epoch 74/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9497 - accuracy: 0.6348 - val_loss: 0.9474 - val_accuracy: 0.6355
# Epoch 75/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9485 - accuracy: 0.6357 - val_loss: 0.9463 - val_accuracy: 0.6367
# Epoch 76/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9473 - accuracy: 0.6362 - val_loss: 0.9450 - val_accuracy: 0.6375
# Epoch 77/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9461 - accuracy: 0.6370 - val_loss: 0.9439 - val_accuracy: 0.6381
# Epoch 78/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9451 - accuracy: 0.6376 - val_loss: 0.9427 - val_accuracy: 0.6387
# Epoch 79/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9439 - accuracy: 0.6385 - val_loss: 0.9418 - val_accuracy: 0.6387
# Epoch 80/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9430 - accuracy: 0.6395 - val_loss: 0.9409 - val_accuracy: 0.6396
# Epoch 81/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9418 - accuracy: 0.6398 - val_loss: 0.9398 - val_accuracy: 0.6400
# Epoch 82/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9407 - accuracy: 0.6414 - val_loss: 0.9389 - val_accuracy: 0.6406
# Epoch 83/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9397 - accuracy: 0.6414 - val_loss: 0.9379 - val_accuracy: 0.6407
# Epoch 84/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9388 - accuracy: 0.6417 - val_loss: 0.9371 - val_accuracy: 0.6427
# Epoch 85/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9377 - accuracy: 0.6420 - val_loss: 0.9362 - val_accuracy: 0.6425
# Epoch 86/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9367 - accuracy: 0.6433 - val_loss: 0.9352 - val_accuracy: 0.6430
# Epoch 87/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9357 - accuracy: 0.6424 - val_loss: 0.9341 - val_accuracy: 0.6429
# Epoch 88/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9347 - accuracy: 0.6439 - val_loss: 0.9335 - val_accuracy: 0.6438
# Epoch 89/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9337 - accuracy: 0.6444 - val_loss: 0.9323 - val_accuracy: 0.6437
# Epoch 90/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9329 - accuracy: 0.6445 - val_loss: 0.9314 - val_accuracy: 0.6443
# Epoch 91/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9320 - accuracy: 0.6452 - val_loss: 0.9306 - val_accuracy: 0.6456
# Epoch 92/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9310 - accuracy: 0.6455 - val_loss: 0.9298 - val_accuracy: 0.6472
# Epoch 93/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9301 - accuracy: 0.6466 - val_loss: 0.9290 - val_accuracy: 0.6468
# Epoch 94/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9291 - accuracy: 0.6463 - val_loss: 0.9282 - val_accuracy: 0.6469
# Epoch 95/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9282 - accuracy: 0.6475 - val_loss: 0.9273 - val_accuracy: 0.6479
# Epoch 96/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9272 - accuracy: 0.6485 - val_loss: 0.9272 - val_accuracy: 0.6490
# Epoch 97/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9264 - accuracy: 0.6484 - val_loss: 0.9255 - val_accuracy: 0.6492
# Epoch 98/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9255 - accuracy: 0.6487 - val_loss: 0.9248 - val_accuracy: 0.6495
# Epoch 99/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9245 - accuracy: 0.6501 - val_loss: 0.9240 - val_accuracy: 0.6507
# Epoch 100/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9237 - accuracy: 0.6511 - val_loss: 0.9230 - val_accuracy: 0.6515

# %% [markdown]
# # Conv1d Evaluation

# %%
learningCurveLoss(history)

# %%
y_pred = makeRoc(X_test, y_test, labels, model, outputSuffix='Conv1d')
