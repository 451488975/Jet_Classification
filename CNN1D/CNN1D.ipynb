# %%
import keras
from keras.layers import Input, Dense, Flatten, Conv1D
from keras.models import load_model, Model
import numpy as np
import sys
import h5py
import yaml
import pandas as pd
import matplotlib.pyplot as plt
from keras.regularizers import l1
from keras.optimizers import Adam
sys.path.insert(0,'../lib')
from train import get_features
from evaluation import makeRoc, learningCurveLoss
# Out:
# Using TensorFlow backend.

# %%
from collections import namedtuple
Option = namedtuple("MyStruct", "inputModel inputFile tree config outputDir ")
options = Option(
    inputModel = 'KERAS_conv1d_weights.h5',
    inputFile = '../processed-pythia82-lhc13-all-pt1-50k-r1_h022_e0175_t220_nonu_withPars_truth_0.z',
    tree = 't_allpar_new',
    config = 'train_config_conv1d.yml',
    outputDir = 'output'
)

print("Loading configuration from", options.config)
config = open(options.config, 'r')
yamlConfig =  yaml.load(config, Loader = yaml.FullLoader)
yamlConfig
# Out:
# Loading configuration from train_config_conv1d.yml
# {'Inputs': ['j1_ptrel',
#   'j1_etarot',
#   'j1_phirot',
#   'j1_erel',
#   'j1_deltaR',
#   'j1_costhetarel',
#   'j1_pdgid',
#   'j_index'],
#  'Labels': ['j_g', 'j_q', 'j_w', 'j_z', 'j_t', 'j_index'],
#  'KerasModel': 'conv1d_model',
#  'KerasModelRetrain': 'conv1d_model_constraint',
#  'KerasLoss': 'categorical_crossentropy',
#  'L1Reg': 0.0001,
#  'NormalizeInputs': 1,
#  'InputType': 'Conv1D',
#  'MaxParticles': 100}

# %% [markdown]
# # Train

# %%
X_train_val, X_test, y_train_val, y_test, labels  = get_features(options, yamlConfig)
# Out:
# (5131613,)
# ('index', 'j_ptfrac', 'j_pt', 'j_eta', 'j_mass', 'j_tau1_b1', 'j_tau2_b1', 'j_tau3_b1', 'j_tau1_b2', 'j_tau2_b2', 'j_tau3_b2', 'j_tau32_b1', 'j_tau32_b2', 'j_zlogz', 'j_c1_b0', 'j_c1_b1', 'j_c1_b2', 'j_c2_b1', 'j_c2_b2', 'j_d2_b1', 'j_d2_b2', 'j_d2_a1_b1', 'j_d2_a1_b2', 'j_m2_b1', 'j_m2_b2', 'j_n2_b1', 'j_n2_b2', 'j_tau1_b1_mmdt', 'j_tau2_b1_mmdt', 'j_tau3_b1_mmdt', 'j_tau1_b2_mmdt', 'j_tau2_b2_mmdt', 'j_tau3_b2_mmdt', 'j_tau32_b1_mmdt', 'j_tau32_b2_mmdt', 'j_c1_b0_mmdt', 'j_c1_b1_mmdt', 'j_c1_b2_mmdt', 'j_c2_b1_mmdt', 'j_c2_b2_mmdt', 'j_d2_b1_mmdt', 'j_d2_b2_mmdt', 'j_d2_a1_b1_mmdt', 'j_d2_a1_b2_mmdt', 'j_m2_b1_mmdt', 'j_m2_b2_mmdt', 'j_n2_b1_mmdt', 'j_n2_b2_mmdt', 'j_mass_trim', 'j_mass_mmdt', 'j_mass_prun', 'j_mass_sdb2', 'j_mass_sdm1', 'j_multiplicity', 'j1_px', 'j1_py', 'j1_pz', 'j1_e', 'j1_pdgid', 'j1_erel', 'j1_pt', 'j1_ptrel', 'j1_eta', 'j1_etarel', 'j1_etarot', 'j1_phi', 'j1_phirel', 'j1_phirot', 'j1_deltaR', 'j1_costheta', 'j1_costhetarel', 'j1_e1mcosthetarel', 'j_g', 'j_q', 'j_w', 'j_z', 'j_t', 'j_undef', 'j_index')
# (98769, 5)

# %% [markdown]
# # Self-Build Model

# %%
l1Reg = yamlConfig['L1Reg']
Inputs = Input(shape = (100,7))
x = Conv1D(filters= 8, kernel_size=4, strides=1, padding='same',
               kernel_initializer='he_normal', use_bias=True, name='conv1_relu_1',
               activation = 'relu', kernel_regularizer=l1(l1Reg))(Inputs)
x = Conv1D(filters= 4, kernel_size=4, strides=2, padding='same',
               kernel_initializer='he_normal', use_bias=True, name='conv1_relu_2',
               activation = 'relu', kernel_regularizer=l1(l1Reg))(x)
x = Conv1D(filters=2, kernel_size=4, strides=3, padding='same',
               kernel_initializer='he_normal', use_bias=True, name='conv1_relu_3',
               activation = 'relu', kernel_regularizer=l1(l1Reg))(x)
x = Flatten()(x)
x = Dense(32, activation='relu', kernel_initializer='lecun_uniform', 
              name='fc1_relu', kernel_regularizer=l1(l1Reg))(x)
predictions = Dense(5, activation='softmax', kernel_initializer='lecun_uniform', name='rnn_densef')(x)
model = Model(inputs=Inputs, outputs=predictions)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100, 7)]          0
# _________________________________________________________________
# conv1_relu_1 (Conv1D)        (None, 100, 8)            232
# _________________________________________________________________
# conv1_relu_2 (Conv1D)        (None, 50, 4)             132
# _________________________________________________________________
# conv1_relu_3 (Conv1D)        (None, 17, 2)             34
# _________________________________________________________________
# flatten (Flatten)            (None, 34)                0
# _________________________________________________________________
# fc1_relu (Dense)             (None, 32)                1120
# _________________________________________________________________
# rnn_densef (Dense)           (None, 5)                 165
# =================================================================
# Total params: 1,683
# Trainable params: 1,683
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = Adam(lr = 0.0001)
model.compile(optimizer=adam, loss=[yamlConfig['KerasLoss']], metrics=['accuracy'])

history = model.fit(X_train_val, y_train_val, batch_size = 1024, epochs = 100, 
                    validation_split = 0.25, shuffle = True, callbacks = None,
                    use_multiprocessing=True, workers=4)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 1s 15ms/step - loss: 1.6982 - accuracy: 0.1905 - val_loss: 1.6660 - val_accuracy: 0.2026
# Epoch 2/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.6511 - accuracy: 0.2128 - val_loss: 1.6314 - val_accuracy: 0.2247
# Epoch 3/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.6219 - accuracy: 0.2353 - val_loss: 1.6070 - val_accuracy: 0.2447
# Epoch 4/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.5988 - accuracy: 0.2551 - val_loss: 1.5852 - val_accuracy: 0.2660
# Epoch 5/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.5764 - accuracy: 0.2740 - val_loss: 1.5620 - val_accuracy: 0.2845
# Epoch 6/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.5511 - accuracy: 0.2926 - val_loss: 1.5344 - val_accuracy: 0.3032
# Epoch 7/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.5207 - accuracy: 0.3135 - val_loss: 1.5008 - val_accuracy: 0.3256
# Epoch 8/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.4838 - accuracy: 0.3376 - val_loss: 1.4608 - val_accuracy: 0.3492
# Epoch 9/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.4413 - accuracy: 0.3644 - val_loss: 1.4164 - val_accuracy: 0.3757
# Epoch 10/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.3964 - accuracy: 0.3945 - val_loss: 1.3719 - val_accuracy: 0.4042
# Epoch 11/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.3539 - accuracy: 0.4213 - val_loss: 1.3318 - val_accuracy: 0.4310
# Epoch 12/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.3161 - accuracy: 0.4458 - val_loss: 1.2962 - val_accuracy: 0.4549
# Epoch 13/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2818 - accuracy: 0.4682 - val_loss: 1.2630 - val_accuracy: 0.4768
# Epoch 14/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2491 - accuracy: 0.4895 - val_loss: 1.2306 - val_accuracy: 0.4985
# Epoch 15/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2176 - accuracy: 0.5092 - val_loss: 1.2001 - val_accuracy: 0.5172
# Epoch 16/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1889 - accuracy: 0.5270 - val_loss: 1.1725 - val_accuracy: 0.5346
# Epoch 17/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1638 - accuracy: 0.5423 - val_loss: 1.1495 - val_accuracy: 0.5499
# Epoch 18/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1430 - accuracy: 0.5536 - val_loss: 1.1299 - val_accuracy: 0.5613
# Epoch 19/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1256 - accuracy: 0.5636 - val_loss: 1.1138 - val_accuracy: 0.5695
# Epoch 20/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1110 - accuracy: 0.5711 - val_loss: 1.1002 - val_accuracy: 0.5764
# Epoch 21/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0984 - accuracy: 0.5795 - val_loss: 1.0889 - val_accuracy: 0.5815
# Epoch 22/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.0881 - accuracy: 0.5836 - val_loss: 1.0786 - val_accuracy: 0.5857
# Epoch 23/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0786 - accuracy: 0.5904 - val_loss: 1.0700 - val_accuracy: 0.5918
# Epoch 24/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.0704 - accuracy: 0.5945 - val_loss: 1.0617 - val_accuracy: 0.5965
# Epoch 25/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0627 - accuracy: 0.5969 - val_loss: 1.0545 - val_accuracy: 0.5992
# Epoch 26/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0554 - accuracy: 0.6015 - val_loss: 1.0472 - val_accuracy: 0.6034
# Epoch 27/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.0485 - accuracy: 0.6040 - val_loss: 1.0406 - val_accuracy: 0.6046
# Epoch 28/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.0420 - accuracy: 0.6070 - val_loss: 1.0343 - val_accuracy: 0.6087
# Epoch 29/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0355 - accuracy: 0.6092 - val_loss: 1.0280 - val_accuracy: 0.6123
# Epoch 30/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.0291 - accuracy: 0.6109 - val_loss: 1.0218 - val_accuracy: 0.6140
# Epoch 31/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.0235 - accuracy: 0.6127 - val_loss: 1.0162 - val_accuracy: 0.6155
# Epoch 32/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.0177 - accuracy: 0.6149 - val_loss: 1.0104 - val_accuracy: 0.6173
# Epoch 33/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.0123 - accuracy: 0.6170 - val_loss: 1.0056 - val_accuracy: 0.6181
# Epoch 34/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.0073 - accuracy: 0.6183 - val_loss: 1.0008 - val_accuracy: 0.6190
# Epoch 35/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0026 - accuracy: 0.6195 - val_loss: 0.9961 - val_accuracy: 0.6214
# Epoch 36/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9983 - accuracy: 0.6218 - val_loss: 0.9919 - val_accuracy: 0.6213
# Epoch 37/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9941 - accuracy: 0.6231 - val_loss: 0.9877 - val_accuracy: 0.6238
# Epoch 38/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9900 - accuracy: 0.6253 - val_loss: 0.9837 - val_accuracy: 0.6249
# Epoch 39/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9864 - accuracy: 0.6263 - val_loss: 0.9800 - val_accuracy: 0.6263
# Epoch 40/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9827 - accuracy: 0.6274 - val_loss: 0.9766 - val_accuracy: 0.6291
# Epoch 41/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9793 - accuracy: 0.6301 - val_loss: 0.9733 - val_accuracy: 0.6283
# Epoch 42/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9759 - accuracy: 0.6308 - val_loss: 0.9703 - val_accuracy: 0.6317
# Epoch 43/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9728 - accuracy: 0.6320 - val_loss: 0.9671 - val_accuracy: 0.6312
# Epoch 44/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9698 - accuracy: 0.6339 - val_loss: 0.9647 - val_accuracy: 0.6352
# Epoch 45/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9669 - accuracy: 0.6350 - val_loss: 0.9618 - val_accuracy: 0.6348
# Epoch 46/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9641 - accuracy: 0.6366 - val_loss: 0.9589 - val_accuracy: 0.6358
# Epoch 47/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9613 - accuracy: 0.6380 - val_loss: 0.9569 - val_accuracy: 0.6381
# Epoch 48/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9590 - accuracy: 0.6389 - val_loss: 0.9541 - val_accuracy: 0.6394
# Epoch 49/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9563 - accuracy: 0.6399 - val_loss: 0.9520 - val_accuracy: 0.6405
# Epoch 50/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9540 - accuracy: 0.6413 - val_loss: 0.9498 - val_accuracy: 0.6413
# Epoch 51/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9517 - accuracy: 0.6428 - val_loss: 0.9477 - val_accuracy: 0.6425
# Epoch 52/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9494 - accuracy: 0.6436 - val_loss: 0.9453 - val_accuracy: 0.6443
# Epoch 53/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9470 - accuracy: 0.6456 - val_loss: 0.9433 - val_accuracy: 0.6469
# Epoch 54/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9449 - accuracy: 0.6468 - val_loss: 0.9414 - val_accuracy: 0.6456
# Epoch 55/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9428 - accuracy: 0.6479 - val_loss: 0.9396 - val_accuracy: 0.6481
# Epoch 56/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9410 - accuracy: 0.6490 - val_loss: 0.9376 - val_accuracy: 0.6494
# Epoch 57/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9389 - accuracy: 0.6507 - val_loss: 0.9360 - val_accuracy: 0.6494
# Epoch 58/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9369 - accuracy: 0.6510 - val_loss: 0.9340 - val_accuracy: 0.6513
# Epoch 59/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9351 - accuracy: 0.6516 - val_loss: 0.9325 - val_accuracy: 0.6519
# Epoch 60/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9333 - accuracy: 0.6532 - val_loss: 0.9310 - val_accuracy: 0.6539
# Epoch 61/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9317 - accuracy: 0.6535 - val_loss: 0.9293 - val_accuracy: 0.6547
# Epoch 62/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9300 - accuracy: 0.6546 - val_loss: 0.9278 - val_accuracy: 0.6548
# Epoch 63/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9283 - accuracy: 0.6560 - val_loss: 0.9263 - val_accuracy: 0.6560
# Epoch 64/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9268 - accuracy: 0.6571 - val_loss: 0.9247 - val_accuracy: 0.6571
# Epoch 65/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9252 - accuracy: 0.6573 - val_loss: 0.9232 - val_accuracy: 0.6573
# Epoch 66/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9237 - accuracy: 0.6589 - val_loss: 0.9219 - val_accuracy: 0.6576
# Epoch 67/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9223 - accuracy: 0.6593 - val_loss: 0.9204 - val_accuracy: 0.6579
# Epoch 68/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9209 - accuracy: 0.6602 - val_loss: 0.9192 - val_accuracy: 0.6582
# Epoch 69/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9195 - accuracy: 0.6611 - val_loss: 0.9181 - val_accuracy: 0.6601
# Epoch 70/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9182 - accuracy: 0.6624 - val_loss: 0.9166 - val_accuracy: 0.6616
# Epoch 71/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9168 - accuracy: 0.6630 - val_loss: 0.9156 - val_accuracy: 0.6612
# Epoch 72/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9155 - accuracy: 0.6631 - val_loss: 0.9144 - val_accuracy: 0.6627
# Epoch 73/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9146 - accuracy: 0.6639 - val_loss: 0.9134 - val_accuracy: 0.6621
# Epoch 74/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9131 - accuracy: 0.6647 - val_loss: 0.9120 - val_accuracy: 0.6647
# Epoch 75/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9121 - accuracy: 0.6648 - val_loss: 0.9115 - val_accuracy: 0.6652
# Epoch 76/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9108 - accuracy: 0.6661 - val_loss: 0.9100 - val_accuracy: 0.6648
# Epoch 77/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9096 - accuracy: 0.6668 - val_loss: 0.9086 - val_accuracy: 0.6666
# Epoch 78/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9084 - accuracy: 0.6677 - val_loss: 0.9077 - val_accuracy: 0.6673
# Epoch 79/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9073 - accuracy: 0.6682 - val_loss: 0.9066 - val_accuracy: 0.6682
# Epoch 80/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9064 - accuracy: 0.6694 - val_loss: 0.9061 - val_accuracy: 0.6689
# Epoch 81/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9052 - accuracy: 0.6692 - val_loss: 0.9048 - val_accuracy: 0.6690
# Epoch 82/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9042 - accuracy: 0.6707 - val_loss: 0.9039 - val_accuracy: 0.6705
# Epoch 83/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9030 - accuracy: 0.6704 - val_loss: 0.9030 - val_accuracy: 0.6708
# Epoch 84/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9020 - accuracy: 0.6712 - val_loss: 0.9019 - val_accuracy: 0.6706
# Epoch 85/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9009 - accuracy: 0.6717 - val_loss: 0.9015 - val_accuracy: 0.6706
# Epoch 86/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9001 - accuracy: 0.6721 - val_loss: 0.9001 - val_accuracy: 0.6721
# Epoch 87/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8992 - accuracy: 0.6730 - val_loss: 0.8993 - val_accuracy: 0.6722
# Epoch 88/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8981 - accuracy: 0.6733 - val_loss: 0.8985 - val_accuracy: 0.6717
# Epoch 89/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8974 - accuracy: 0.6738 - val_loss: 0.8974 - val_accuracy: 0.6734
# Epoch 90/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8962 - accuracy: 0.6739 - val_loss: 0.8968 - val_accuracy: 0.6732
# Epoch 91/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8955 - accuracy: 0.6754 - val_loss: 0.8954 - val_accuracy: 0.6742
# Epoch 92/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8944 - accuracy: 0.6749 - val_loss: 0.8948 - val_accuracy: 0.6739
# Epoch 93/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8938 - accuracy: 0.6744 - val_loss: 0.8937 - val_accuracy: 0.6749
# Epoch 94/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8928 - accuracy: 0.6753 - val_loss: 0.8929 - val_accuracy: 0.6753
# Epoch 95/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8921 - accuracy: 0.6764 - val_loss: 0.8922 - val_accuracy: 0.6755
# Epoch 96/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8913 - accuracy: 0.6762 - val_loss: 0.8914 - val_accuracy: 0.6757
# Epoch 97/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8903 - accuracy: 0.6768 - val_loss: 0.8907 - val_accuracy: 0.6759
# Epoch 98/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8894 - accuracy: 0.6772 - val_loss: 0.8896 - val_accuracy: 0.6769
# Epoch 99/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8890 - accuracy: 0.6774 - val_loss: 0.8890 - val_accuracy: 0.6763
# Epoch 100/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8880 - accuracy: 0.6782 - val_loss: 0.8889 - val_accuracy: 0.6775

# %% [markdown]
# # Conv1d Evaluation

# %%
learningCurveLoss(history)

# %%
y_pred = makeRoc(X_test, y_test, labels, model, outputSuffix='Conv1d')
